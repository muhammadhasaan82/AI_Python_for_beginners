# %% [markdown]
# AI Python for Beginners

# %%
print("Hello")
# Out:
# Hello

# %%
name = "Muhammad Hasaan"
age = 23
Degree = "BS-AI"
Institute = "SMIU"
Profession = "Data Scientist"
seniority = "Associate"
company = "NexGenTeck"

print(type(name), type(age), type(Institute), type(Degree), type(Profession), type(seniority), type(company))
# Out:
# <class 'str'> <class 'int'> <class 'str'> <class 'str'> <class 'str'> <class 'str'> <class 'str'>

# %%
print(f"Hi, I am {name}.\n I am {age:.0f} years old.\n Currently, I am pursuing degree in {Degree} from {Institute}.\n I am working as {seniority} at {company}.")
# Out:
# Hi, I am Muhammad Hasaan.
#  I am 23 years old.
#  Currently, I am pursuing degree in BS-AI from SMIU.
#  I am working as Associate at NexGenTeck.

# %%
from helper_functions import print_LLM_response
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from helper_functions import print_LLM_response
#
# ModuleNotFoundError: No module named 'helper_functions'

# %%
pip install helper_functions
# Out:
# ...
#   Using cached helper_functions-2.0.11.tar.gz (6.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
# ...

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------------- -------------------------- 2.6/8.0 MB 24.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.0 MB 16.3 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 10.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 7.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/8.0 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 5.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.3 MB 3.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/12.3 MB 3.2 MB/s eta 0:00:04
# ...

# %%
colors = [
         "Blue",
         "Green",
         "Yellow",
         "Red"
]

for color in colors:
       prompt = f"""My favourite color is {color}"""
print(prompt)
# Out:
# My favourite color is Red

# %%
vegetable_descriptions = {
    "carrot": "Orange and crunchy",
     "potato": "Brown and starchy",
     "tomato": "Red and juicy",
      "onion": "White and pungent"
}

# %%
print(vegetable_descriptions["carrot"])
# Out:
# Orange and crunchy

# %%
person_contact = {
    "name": "Isabel",
    "age": 29,
    "phone number": "+1-234-5678"
}

# %%
person_contact["age"] = 30

# %%
print(person_contact["age"])
# Out:
# 30

# %%
fruit_list = ["apple", "orange", "banana"]

# %%
fruit_list.append("grapes")

# %%
print(fruit_list)
# Out:
# ['apple', 'orange', 'banana', 'grapes']

# %%
age = 20

if age >= 18:
    print("Access granted")
else:
    print("Access denied")
# Out:
# Access granted

# %%
username = "admin"
password = "1234"

if username == "admin" or password == "admin123":
    print("Access granted")
else:
    print("Access denied")
# Out:
# Access granted

# %%
updated_progress = """I completed Module 3 of DeepLearning.AI's AI Python for Beginners."""

f = open("my_progress.txt", "w")
f.write(updated_progress)
f.close()

f = open("my_progress.txt", "r")
progress = f.read()
f.close()

print(progress)
# Out:
# I completed Module 3 of DeepLearning.AI's AI Python for Beginners.
