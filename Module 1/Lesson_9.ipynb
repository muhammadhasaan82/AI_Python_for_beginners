# %% [markdown]
# # L9: Building LLM prompts with variables

# %% [markdown]
# In the next cell, you will import the function `print_llm_response` that uses an LLM with an instruction that you provide as a string and displays the result.

# %%
from helper_functions import print_llm_response

# %% [markdown]
# Basically, you can use that function as if you were asking a chatbot. You just need to provide your instructions as a string. For instance, you can ask "What is the capital of France?" using the following code:

# %%
print_llm_response("What is the capital of France?")
# Out:
# The capital of France is Paris.

# %% [markdown]
# Let's ask the LLM for the lifestyle description for Otto Matic, whose name is stored in `name`, if he were a `dog_age` years old dog.

# %%
name = "Otto Matic"
dog_age = 21/7

# %%
print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might 
entail in terms of energy level, interests, and behavior.""")
# Out:
# At 3.0 years old, a dog is typically in the prime of adulthood. This life stage usually features:
#
# - **Energy Level:** High to moderate energy; the dog is active and playful but more controlled than a puppy.
# - **Interests:** Enjoys regular exercise, playtime, socializing, and mental stimulation.
# - **Behavior:** Generally well-trained, confident, and stable; may show some independence but remains affectionate and engaged with owners.

# %% [markdown]
# <b>You just used AI with your own variables!</b> You used an LLM with instructions that included variables you defined in this notebook.
#
# <b>Congratulations 🎉🎉🎉</b>

# %% [markdown]
# ## Variable names restrictions

# %% [markdown]
# The following variable names also have some problems. Try to fix them yourself or use the help from the chatbot.

# %%
driver = "unicorn"
drivers_vehicle = "colorful, asymmetric dinosaur car"
favorite_planet = "Pluto"

# %% [markdown]
# Now, update the next cell with any changes you made in the previous cell.

# %%
print_llm_response(f"""Write me a 300 word children's story about a {driver} racing
a {drivers_vehicle} for the {favorite_planet} champion cup.""")
# Out:
# In the magical land of Glitterville, a sparkling unicorn named Luna was preparing for the biggest race of the year—the Pluto Champion Cup. The race was famous for its wild twists and turns across the shimmering Crystal Plains.
#
# Luna’s opponent was no ordinary racer. It was a colorful, asymmetric dinosaur car named DinoDash. DinoDash had bright purple spots, one giant green wheel, and a tiny red tail that wiggled when it zoomed. Everyone said DinoDash was the fastest and quirkiest racer on Pluto.
#
# The day of the race arrived. The crowd cheered as Luna’s hooves sparkled with magic and DinoDash’s engine roared with excitement. The race began with a flash of light!
#
# Luna galloped gracefully, her mane flowing like a rainbow. DinoDash zipped ahead, wobbling but steady. They raced over glittering hills, through sparkling caves, and around glowing trees.
#
# Halfway through, DinoDash’s big green wheel hit a bump and wobbled wildly. Luna slowed down, worried her friend might crash. But DinoDash smiled and said, “Don’t worry, Luna! I’ve got this!”
#
# With a burst of speed, DinoDash balanced perfectly and zoomed ahead. Luna laughed and used her magic to create a sparkling path, making the race even more exciting.
#
# As they neared the finish line, Luna and DinoDash were neck and neck. The crowd held their breath. With one last burst, Luna’s hooves and DinoDash’s wheels crossed the line together!
#
# The judges smiled and declared, “It’s a tie! Luna and DinoDash are both champions!”
#
# Luna and DinoDash hugged, happy to share the victory. They learned that racing was not just about winning but about friendship and fun.
#
# From that day on, Luna and DinoDash raced together, making every Pluto Champion Cup a magical adventure!

# %% [markdown]
# ## Extra practice
#
# Try the exercises below to practice the concepts from this lesson. Read the comments in each cell with the instructions for each exercise.
#
# <b>Feel free to use the chatbot if you need help.</b>

# %%
# Fix this code
favorite_book = "1001 Ways to Wear a Hat"
second_fav_book = "2002 Ways to Wear a Scarf"
print(f"My most favorite book is {favorite_book}, but I also like {second_fav_book}")
# Out:
# My most favorite book is 1001 Ways to Wear a Hat, but I also like 2002 Ways to Wear a Scarf

# %%
# Make variables for your favorite game, movie, and food.
# Then use print_llm_response to ask the LLM to recommend you
# a new song to listen to based on your likes.
favorite_game = "PUBG & GTA V"
movie = "Stranger Things"
food = "Ramen"
print_llm_response(f"""Write 300 words on my personality as my favorite game is {favorite_game} and movie is {movie} along {food}
and also recommend what a new song to listen to based on my likes

""")
# Out:
# Your personality reflects a dynamic blend of adventure, strategy, and a taste for immersive storytelling. Enjoying PUBG and GTA V shows you thrive on excitement and challenge. PUBG’s intense, tactical gameplay suggests you are strategic, quick-thinking, and enjoy testing your skills under pressure. Meanwhile, GTA V’s open-world freedom and complex narratives indicate you appreciate creativity, exploration, and a bit of rebellious fun. You likely enjoy balancing structure with spontaneity, valuing both planning and the thrill of unexpected moments.
#
# Your favorite movie, Stranger Things, adds another layer to your personality. The show’s mix of supernatural mystery, 80s nostalgia, and strong friendships suggests you have a curiosity for the unknown and a deep appreciation for storytelling that combines suspense with emotional depth. You probably enjoy connecting with characters and narratives that explore loyalty, courage, and the power of teamwork.
#
# Ramen as a favorite food complements this personality well. It’s comforting yet diverse, reflecting your ability to enjoy simple pleasures while appreciating complexity and variety. Just like your gaming and viewing preferences, ramen offers a balance of warmth, flavor, and creativity.
#
# Based on your interests, I recommend listening to “Blinding Lights” by The Weeknd. This song combines an energetic, retro vibe with modern production, much like how Stranger Things blends 80s nostalgia with contemporary storytelling. Its upbeat tempo and catchy melody match the adrenaline rush of PUBG and GTA V, making it a perfect soundtrack for your adventurous and immersive personality.
